# %%
import pickle
model = pickle.load(open('finalized_model.sav','rb'))

prediction_input=int(input("Enter the year of Experience(int value only):"))
future_prediction=model.predict([[prediction_input]])
print(f"Future_Prediction {future_prediction}")
# Out:
# Enter the year of Experience(int value only): 10
# Future_Prediction [[120275.61667525]]
# C:\Users\s.sangar\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
